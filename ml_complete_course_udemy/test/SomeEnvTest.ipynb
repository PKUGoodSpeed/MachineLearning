# %%
import numpy as np
import pandas as pd
import seaborn as sns
from IPython.display import display
from matplotlib import pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
df = sns.load_dataset('iris')
display(df[:5])
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
des = df.describe()
print(type(des))
display(des)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
df.groupby('species').size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
sns.pairplot(df, hue='species', size=3.2, aspect=1.)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.hist(edgecolor='black', linewidth=1.2, figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f01a4b2e390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f01a4724ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f01a46ce9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f01a46fe470>]],
#       dtype=object)

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2,2,1)
sns.violinplot(x='species', y='petal_length', data=df)
plt.subplot(2,2,2)
sns.violinplot(x='species', y='petal_width', data=df)
plt.subplot(2,2,3)
sns.violinplot(x='species', y='sepal_length', data=df)
plt.subplot(2,2,4)
sns.violinplot(x='species', y='sepal_width', data=df)

# %%
df.boxplot(by='species', figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f01a4508da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f01a44b6a58>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f01a4466278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f01a4213a20>]],
#       dtype=object)

# %%
pd.scatter_matrix(df, figsize=(12, 8))
plt.show()
# Out:
# /home/goodspeed/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
